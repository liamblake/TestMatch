# %%
import numpy as np
from pandas import read_csv, DataFrame
from keras import models, layers
from keras.metrics import Precision as precision
import keras.backend as kb
import matplotlib.pyplot as plt
#import keras2onnx
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import normalize
from scipy import interp
from scipy.stats import boxcox
from itertools import cycle

# %%
# Global variables
PREDS_NUM = ["match_balls", "inn_balls", "team_score", "team_lead", "bat_score", "bat_balls", "bat_avg", "career_bat_balls", "bat_sr", "bowl_balls", "bowl_runs", "career_bowl_balls", "bowl_avg", "bowl_sr", "bat_team_total_runs", "bat_team_total_wkts", "bowl_team_total_runs", "bowl_team_total_wkts"]
PREDS_CAT = [""]

# %% [markdown]
# # Pre-processing
# This is informed from EDA performed in R

# %%
def preprocess(x, params = [None]*len(PREDS_NUM)):
    opt_params = [None]*len(PREDS_NUM)
    trans = [""]*len(PREDS_NUM)
    
    
    # Box-cox transform of bat_avg, bat_sr, bowl_avg
    for i in range(13):#6,8,12]:
        if PREDS_NUM[i] == "team_lead":
            continue
        
        trans[i] = "Box-Cox"
        x[:,i], opt_params[i] = boxcox(x[:,i] + 1) if params[i] == None else (boxcox(x[:,i] + 1, params[i]), None)
        # Adding shift parameter 1 ensures all data is positive
    
    # Normalise all numeric features
    x[:,:len(PREDS_NUM)] = normalize(x[:,:len(PREDS_NUM)], axis = 0)
    
    
    return x, DataFrame(data = {'Predictor': PREDS_NUM, 'Transformation': trans, 'Parameters': opt_params})

# %% [markdown]
# # Predicting Wicket

# %% [markdown]
# ## Load data

# %%
# Load data
train_pred_wkt = read_csv("data/is_wkt_train_preds.csv")
train_out_wkt = read_csv("data/is_wkt_train_labs.csv")
test_pred_wkt = read_csv("data/is_wkt_test_preds.csv")
test_out_wkt = read_csv("data/is_wkt_test_labs.csv")

# Preprocess
train_x_wkt, trans = preprocess(train_pred_wkt.to_numpy())
test_x_wkt, _ = preprocess(test_pred_wkt.to_numpy(), params = trans['Parameters'].tolist())
train_y_wkt = train_out_wkt.to_numpy()
test_y_wkt = test_out_wkt.to_numpy()

# Validation set
val_prop_wkt = int(np.ceil(train_x_wkt.shape[0]/10))
x_val_wkt = train_x_wkt[:val_prop_wkt]
partial_x_train_wkt = train_x_wkt[val_prop_wkt:]
y_val_wkt = train_y_wkt[:val_prop_wkt]
partial_y_train_wkt = train_y_wkt[val_prop_wkt:]

codes_wkt = ["no",  "W"]
n_classes_wkt = train_y_wkt.shape[1]

# %%
trans
# Out:
#                Predictor Transformation  Parameters
# 0            match_balls        Box-Cox    0.607960
# 1              inn_balls        Box-Cox    0.459530
# 2             team_score        Box-Cox    0.427892
# 3              team_lead                        NaN
# 4              bat_score        Box-Cox    0.187960
# 5              bat_balls        Box-Cox    0.214228
# 6                bat_avg        Box-Cox    0.577472
# 7       career_bat_balls        Box-Cox    0.182619
# 8                 bat_sr        Box-Cox    0.643371
# 9             bowl_balls        Box-Cox    0.374149
# 10             bowl_runs        Box-Cox    0.351410
# 11     career_bowl_balls        Box-Cox    0.154421
# 12              bowl_avg        Box-Cox   -0.636282
# 13               bowl_sr                        NaN
# 14   bat_team_total_runs                        NaN
# 15   bat_team_total_wkts                        NaN
# 16  bowl_team_total_runs                        NaN
# 17  bowl_team_total_wkts                        NaN

# %%
# Data dimensions
print("Training set:", train_x_wkt.shape)
print("Training set:", test_x_wkt.shape)

print("\nObservations under each label")
print(DataFrame({'Label': codes_wkt, 
                 'Training': [train_y_wkt.shape[0] - np.sum(train_y_wkt), np.sum(train_y_wkt)],
                 'Testing': [test_y_wkt.shape[0] - np.sum(test_y_wkt), np.sum(test_y_wkt)]}))
# Out:
# Training set: (506562, 72)
# Training set: (168854, 72)
#
# Observations under each label
#   Label  Training  Testing
# 0    no    498401   166198
# 1     W      8161     2656

# %% [markdown]
# ## Prediction Model

# %%
# Define model
model_wkt = models.Sequential()
model_wkt.add(layers.Dense(512, activation='relu', input_shape=(train_x_wkt.shape[1],)))
model_wkt.add(layers.Dense(512, activation='relu'))
model_wkt.add(layers.Dense(n_classes_wkt, activation='sigmoid'))

# Compile model
model_wkt.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=[precision()])

# %%
# Train model
history_wkt = model_wkt.fit(partial_x_train_wkt,
partial_y_train_wkt,
epochs=10,
batch_size=512,
validation_data=(x_val_wkt, y_val_wkt))
# Out:
# Train on 455905 samples, validate on 50657 samples
# Epoch 1/10
# 455905/455905 [==============================] - 16s 35us/step - loss: 0.0845 - precision_1: 0.0215 - val_loss: 0.0794 - val_precision_1: 0.0000e+00
# Epoch 2/10
# 455905/455905 [==============================] - 33s 73us/step - loss: 0.0828 - precision_1: 0.0000e+00 - val_loss: 0.0811 - val_precision_1: 0.0000e+00
# Epoch 3/10
# 455905/455905 [==============================] - 33s 73us/step - loss: 0.0824 - precision_1: 0.0000e+00 - val_loss: 0.0792 - val_precision_1: 0.0000e+00
# Epoch 4/10
# 455905/455905 [==============================] - 33s 72us/step - loss: 0.0823 - precision_1: 0.0000e+00 - val_loss: 0.0790 - val_precision_1: 0.0000e+00
# Epoch 5/10
# 455905/455905 [==============================] - 395s 867us/step - loss: 0.0821 - precision_1: 0.0000e+00 - val_loss: 0.0797 - val_precision_1: 0.0000e+00
# Epoch 6/10
# 455905/455905 [==============================] - 19s 42us/step - loss: 0.0821 - precision_1: 0.0000e+00 - val_loss: 0.0791 - val_precision_1: 0.0000e+00
# Epoch 7/10
# 455905/455905 [==============================] - 17s 36us/step - loss: 0.0821 - precision_1: 0.0000e+00 - val_loss: 0.0802 - val_precision_1: 0.0000e+00
# Epoch 8/10
# 455905/455905 [==============================] - 16s 36us/step - loss: 0.0820 - precision_1: 0.0000e+00 - val_loss: 0.0798 - val_precision_1: 0.0000e+00
# Epoch 9/10
# 455905/455905 [==============================] - 18s 39us/step - loss: 0.0819 - precision_1: 0.0000e+00 - val_loss: 0.0794 - val_precision_1: 0.0000e+00
# Epoch 10/10
# 455905/455905 [==============================] - 25s 54us/step - loss: 0.0819 - precision_1: 0.0000e+00 - val_loss: 0.0793 - val_precision_1: 0.0000e+00

# %%
model_wkt.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 512)               37376
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 300,545
# Trainable params: 300,545
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss = history_wkt.history['loss']
val_loss = history_wkt.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history_wkt.history['accuracy']
val_acc = history_wkt.history['val_accuracy']
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-e8409604ac04> in <module>
# ----> 1 acc = history_wkt.history['accuracy']
#       2 val_acc = history_wkt.history['val_accuracy']
#       3 plt.plot(epochs, acc, 'bo', label='Training acc')
#       4 plt.plot(epochs, val_acc, 'b', label='Validation acc')
#       5 plt.title('Training and validation accuracy')
#
# KeyError: 'accuracy'

# %%
# Predictions on test set
test_pred = model_wkt.predict(test_x_wkt)

# Plot linewidth.
lw = 2

# Compute ROC curve and ROC area for each class
fpr, tpr, _ = roc_curve(test_y_wkt, test_pred)
roc_auc = auc(fpr, tpr)

color = "red"

# Plot ROC curve
plt.plot(fpr, tpr, color=color, lw=lw,
         label='ROC curve of class {0} (area = {1:0.2f})'
         ''.format(0, roc_auc))
plt.title("W")
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.show()

print("AUC:", roc_auc)
#print("Accuracy:", accuracy(test_y_wkt, test_pred))
# Out:
# AUC: 0.5850990923223092

# %% [markdown]
# # Predicting Outcome

# %%
# Load data
train_pred_out = read_csv("data/outcome_train_preds.csv")
train_out_out = read_csv("data/outcome_train_labs.csv")
test_pred_out = read_csv("data/outcome_test_preds.csv")
test_out_out = read_csv("data/outcome_test_labs.csv")

train_x_out = train_pred_out.to_numpy()
test_x_out = test_pred_out.to_numpy()
train_y_out = train_out_out.to_numpy()
test_y_out = test_out_out.to_numpy()

# Validation set
val_prop_out = int(np.ceil(train_x_out.shape[0]/10))
x_val_out = train_x_out[:val_prop_out]
partial_x_train_out = train_x_out[val_prop_out:]
y_val_out = train_y_out[:val_prop_out]
partial_y_train_out = train_y_out[val_prop_out:]

codes_out = ["b", "lb", "nb", "off_bat", "wd"]
n_classes_out = train_y_out.shape[1]

# %%
# Define model
model_out = models.Sequential()
model_out.add(layers.Dense(512, activation='relu', input_shape=(train_x_out.shape[1],)))
model_out.add(layers.Dense(512, activation='relu'))
model_out.add(layers.Dense(n_classes_out, activation='softmax'))

# Compile model
model_out.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train model
history_out = model_out.fit(partial_x_train_out,
partial_y_train_out,
epochs=10,
batch_size=512,
validation_data=(x_val_out, y_val_out))
# Out:
# Epoch 1/10
# 877/877 [==============================] - 6s 6ms/step - loss: 0.1150 - accuracy: 0.9814 - val_loss: 0.1238 - val_accuracy: 0.9818
# Epoch 2/10
# 877/877 [==============================] - 5s 6ms/step - loss: 0.1105 - accuracy: 0.9825 - val_loss: 0.1130 - val_accuracy: 0.9818
# Epoch 3/10
# 877/877 [==============================] - 5s 6ms/step - loss: 0.1096 - accuracy: 0.9825 - val_loss: 0.1153 - val_accuracy: 0.9818
# Epoch 4/10
# 877/877 [==============================] - 5s 6ms/step - loss: 0.1092 - accuracy: 0.9825 - val_loss: 0.1145 - val_accuracy: 0.9818
# Epoch 5/10
# 877/877 [==============================] - 5s 6ms/step - loss: 0.1088 - accuracy: 0.9825 - val_loss: 0.1137 - val_accuracy: 0.9818
# Epoch 6/10
# 877/877 [==============================] - 5s 6ms/step - loss: 0.1086 - accuracy: 0.9825 - val_loss: 0.1129 - val_accuracy: 0.9818
# Epoch 7/10
# 877/877 [==============================] - 5s 6ms/step - loss: 0.1085 - accuracy: 0.9825 - val_loss: 0.1122 - val_accuracy: 0.9818
# Epoch 8/10
# 877/877 [==============================] - 5s 6ms/step - loss: 0.1086 - accuracy: 0.9825 - val_loss: 0.1138 - val_accuracy: 0.9818
# Epoch 9/10
# 877/877 [==============================] - 5s 6ms/step - loss: 0.1082 - accuracy: 0.9825 - val_loss: 0.1188 - val_accuracy: 0.9818
# Epoch 10/10
# 877/877 [==============================] - 5s 6ms/step - loss: 0.1082 - accuracy: 0.9825 - val_loss: 0.1157 - val_accuracy: 0.9818

# %%
loss = history_out.history['loss']
val_loss = history_out.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history_out.history['accuracy']
val_acc = history_out.history['val_accuracy']
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %%
# Predictions on test set
test_pred = model_out.predict(test_x_out)

# Plot linewidth.
lw = 2

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes_out):
    fpr[i], tpr[i], _ = roc_curve(test_y_out[:, i], test_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])



# Plot all ROC curves

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes_out), colors):
    #plt.subplot(11,2,i + 1)
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))
    plt.title(codes_out[i])
    plt.plot([0, 1], [0, 1], 'k--', lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.show()
    print(codes_out[i], roc_auc[i])
# Out:
# b 0.5988316389633224
# lb 0.7324254420964164
# nb 0.6198347413067532
# off_bat 0.7008294392656543
# wd 0.5500969751159093

# %% [markdown]
# # Ignore, for reference

# %%
# Load data
train_pred = read_csv("data/bbb_train_preds.csv")
train_out = read_csv("data/bbb_train_labs.csv")
test_pred = read_csv("data/bbb_test_preds.csv")
test_out = read_csv("data/bbb_test_labs.csv")

train_x = train_pred.to_numpy()
test_x = test_pred.to_numpy()
train_y = train_out.to_numpy()
test_y = test_out.to_numpy()

# Validation set
val_prop = int(np.ceil(train_x.shape[0]/10))
x_val = train_x[:val_prop]
partial_x_train = train_x[val_prop:]
y_val = train_y[:val_prop]
partial_y_train = train_y[val_prop:]

codes = ["1",  "1b",  "1lb", "1nb", "1wd", "2",   "2b",  "2lb", "2nb", "2wd", "3",   "3b",  "3lb", "4", "4b", "4lb", "5", "5nb", "5wd", "6", "W", "0"]
n_classes = train_y.shape[1]

# %%
# Define model
model = models.Sequential()
model.add(layers.Dense(128, activation='relu', input_shape=(train_x.shape[1],)))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(n_classes, activation='softmax'))

# Compile model
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train model
history = model.fit(partial_x_train,
partial_y_train,
epochs=20,
batch_size=512,
validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 911/911 [==============================] - 2s 2ms/step - loss: 8.5148 - accuracy: 0.6396 - val_loss: 1.0479 - val_accuracy: 0.7132
# Epoch 2/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0501 - accuracy: 0.7157 - val_loss: 1.0438 - val_accuracy: 0.7132
# Epoch 3/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0411 - accuracy: 0.7159 - val_loss: 1.0435 - val_accuracy: 0.7132
# Epoch 4/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0413 - accuracy: 0.7159 - val_loss: 1.0440 - val_accuracy: 0.7132
# Epoch 5/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0448 - accuracy: 0.7159 - val_loss: 1.0439 - val_accuracy: 0.7132
# Epoch 6/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0394 - accuracy: 0.7159 - val_loss: 1.0435 - val_accuracy: 0.7132
# Epoch 7/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0393 - accuracy: 0.7159 - val_loss: 1.0435 - val_accuracy: 0.7132
# Epoch 8/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0394 - accuracy: 0.7159 - val_loss: 1.0437 - val_accuracy: 0.7132
# Epoch 9/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0393 - accuracy: 0.7159 - val_loss: 1.0434 - val_accuracy: 0.7132
# Epoch 10/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0393 - accuracy: 0.7159 - val_loss: 1.0435 - val_accuracy: 0.7132
# Epoch 11/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0393 - accuracy: 0.7159 - val_loss: 1.0436 - val_accuracy: 0.7132
# Epoch 12/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0393 - accuracy: 0.7159 - val_loss: 1.0435 - val_accuracy: 0.7132
# Epoch 13/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0393 - accuracy: 0.7159 - val_loss: 1.0434 - val_accuracy: 0.7132
# Epoch 14/20
# 911/911 [==============================] - ETA: 0s - loss: 1.0388 - accuracy: 0.71 - 2s 2ms/step - loss: 1.0393 - accuracy: 0.7159 - val_loss: 1.0435 - val_accuracy: 0.7132
# Epoch 15/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0393 - accuracy: 0.7159 - val_loss: 1.0434 - val_accuracy: 0.7132
# Epoch 16/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0393 - accuracy: 0.7159 - val_loss: 1.0433 - val_accuracy: 0.7132
# Epoch 17/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0393 - accuracy: 0.7159 - val_loss: 1.0434 - val_accuracy: 0.7132
# Epoch 18/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0393 - accuracy: 0.7159 - val_loss: 1.0436 - val_accuracy: 0.7132
# Epoch 19/20
# 911/911 [==============================] - 2s 2ms/step - loss: 1.0393 - accuracy: 0.7159 - val_loss: 1.0436 - val_accuracy: 0.7132
# Epoch 20/20
# 911/911 [==============================] - ETA: 0s - loss: 1.0389 - accuracy: 0.71 - 2s 2ms/step - loss: 1.0393 - accuracy: 0.7159 - val_loss: 1.0434 - val_accuracy: 0.7132

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %%
# Export model to ONNX
output_model_path = "../backend/models/keras_bbb.onnx"
onnx_model = keras2onnx.convert_keras(model, model.name)
keras2onnx.save_model(onnx_model, output_model_path)
# Out:
# tf executing eager_mode: True
# tf.keras model eager_mode: False
# The ONNX operator number change on the optimization: 19 -> 15
# The maximum opset needed by this model is only 9.

# %%
# Predictions on test set
test_pred = model.predict(test_x)

# Plot linewidth.
lw = 2

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(test_y[:, i], test_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])



# Plot all ROC curves

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    #plt.subplot(11,2,i + 1)
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))
    plt.title(codes[i])
    plt.plot([0, 1], [0, 1], 'k--', lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.show()

# %% [markdown]
# # Bootstrapping Fit
